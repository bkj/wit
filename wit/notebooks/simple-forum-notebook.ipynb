# %% [markdown]
# ### Schema Alignment Example

# %%
import keras
import urllib2

import pandas as pd

from hashlib import md5
from pprint import pprint
from bs4 import BeautifulSoup
from sklearn.cluster import DBSCAN

import sys
sys.path.append('/Users/BenJohnson/projects/what-is-this/wit/')
from wit import *
# Out:
# Using Theano backend.

# %% [markdown]
# #### Task
#
# We attempt to approach the problem of "schema alignment": given two datasets that contain roughly the same kinds of data, merge them into a single dataset such that columns are appropriately aligned.  This is a generic problem that comes up when we're trying to merge data, but in this example we explore it's application to data attained via web scraping.
#
# Specifically, we'll try to do this with data scraped from message board forums, which contains data types such as
#
#     username
#     post body
#     signature
#     date
#     ...
#
# So the task is to align the username field in the first dataset with the username field in the second dataset, etc.  The usual approach is to write/configure a parser for each schema, which includes a manual mapping of data fields from the HTML page to
#
# #### Data
#
# We'll use data scraped by Hyperion Gray from
#
#     remingtonsociety.com
#     marauderairrifle.com
#
# A post in the first set looks like:
# ```html
# <tr class="row1">
#     <td align="center" class="row" valign="top">
#         <a name="p6755"></a>
#         <div class="postauthor">Noel</div>
#         <div class="postdetails">
#                 <br/> <b>Joined:</b> Tue Jun 26, 2007 8:48 pm
#                 <br/> <b>Posts: </b> 112
#         </div>
#         <img alt="" height="1" src="spacer.gif" width="120"/>
#     </td>
#     <td class="row" height="25" valign="top" width="100%">
#         <div style="float: right;"></div>
#         <div class="postsubject">
#             <a href="./viewtopic.php?p=6755#p6755">
#                 <img alt="Post" height="9" src="icon_topic_latest.gif" title="Post" width="13"/>
#             </a>
#             Remington 12A wanted
#         </div>
#         <div class="postbody">
#             Looking for a 12A with condition. Bore must be very good plus, external at 80% or better please.
#         </div>
#         <g:plusone size="small"></g:plusone>
#         <br clear="all"/><br/>
#     </td>
# </tr>
# ```
#
# A post in the second set looks like:
# ```html
# <div class="post bg2" id="p38336">
#     <div class="inner">
#         <span class="corners-top">
#             <span></span>
#         </span>
#         <div class="postbody">
#             <h3 class="first">
#                 <a href="#p38336">Re: Is this what we need for 22 M-rod accuracy?</a>
#             </h3>
#             <p class="author">
#                 <a href="./viewtopic.php?p=38336#p38336">
#                     <img alt="Post" height="9" src="icon_post_target.gif" title="Post" width="11"/>
#                 </a>
#                 by
#                 <strong>
#                     <a href="./memberlist.php?mode=viewprofile&amp;u=1195">
#                         RayK
#                     </a>
#                 </strong>
#                 » Tue May 28, 2013 9:18 pm
#             </p>
#             <div class="content">
#                 Thanks for the new photos!  Those are great and clearly show the idea.<br/><br/>Mine currently look just like that... <br/><br/>Ray
#             </div>
#             <div class="signature" id="sig38336">
#                 25 W-rod | 8 shots @ 70 FPE -2% | 3100 fill<br/>25 M-rod
#             </div>
#         </div>
#         <dl class="postprofile" id="profile38336">
#             <dt>
#                 <a href="./memberlist.php?mode=viewprofile&amp;u=1195">RayK</a>
#             </dt>
#             <dd></dd>
#             <dd><strong>Posts:</strong> 5311</dd>
#             <dd><strong>Joined:</strong> Sat Jun 05, 2010 3:19 pm</dd>
#         </dl>
#         <div class="back2top">
#             <a class="top" href="#wrap" title="Top">
#                 Top
#             </a>
#         </div>
#         <span class="corners-bottom"><span></span></span>
#     </div>
# </div>
# ```
#
# They have somewhat similar structure, and actually look like maybe they were generated by a different configuration of the same forum building software.  However, they're sufficiently different that they cannot be parsed with the same CSS selectors or regular expressions.
#
# #### Approach
#
# There are a few stages to this problem:
#
#     a) Finding 'atomic data elements' in the raw HTML page.
#         - i.e. separating the posts on a page that has multiple posts
#
#     b) Finding the 'data fields' within an atomic data element
#         - i.e. finding the locations in the DOM that contain data points we're interested in capturing.
#
#     c) Merging 'data fields' across schema
#
# a) and b) are difficult in their own right, and we implement simple, non-optimal solutions.  For a), we totally punt and just do it manually.  For b):
#
#     - find all nodes that contain text in the corpus of posts
#     - find CSS paths of the format
#
#         tag1[class1, ...] > tag2[class2, ...] > ... > tag_n[class_m, ...]
#
#       to each of these nodes.  From here on, when we say "CSS path", we mean CSS path w/ classes, w/o indices.
#     - assume data in nodes with the same CSS path are "equivalent".
#
# The last step is an assumption that could be wrong in both directions: data elements with the same CSS path could be different latent variables, and data elements with different CSS paths could be the same latent variables.  These issues could be mitigated by applying more advanced wrapper induction techniques, but they do not turn out to be too damaging to the current approach.  In fact, the process of merging two schemas also merges classes within the same schema (for better or for worse).

# %% [markdown]
# Set parameters

# %%
num_features = 75  # in characters
max_len      = 350 # in characters
formatter    = KerasFormatter(num_features, max_len)

# %% [markdown]
# Load data from two forums with different schemas.
#
# ```
# origin : domain that record comes from
# hash   : md5 hash of the path to the elements in the DOM (including classes)
# id     : record number within origin + md5 hash of origin field
# obj    : text content of DOM node
# src    : corresponding raw HTML markup
# ```

# %%
df = pd.read_csv('data/simple-forum-dataset.csv')
df.tail()
# Out:
#               hash          id  \
# 23229  e5316-48774  2662-48774
# 23230  3122c-48774  2662-48774
# 23231  df7d2-48774  2662-48774
# 23232  5fd24-48774  2662-48774
# 23233  5fd24-48774  2662-48774
#
#                                                      obj  \
# 23229               by jer295  Sat Mar 09, 2013 9:34 pm
# 23230  Standard oring are to fat to work the one that...
# 23231                                             jer295
# 23232                                           Posts: 8
# 23233                   Joined: Thu Mar 07, 2013 7:33 am
#
#                                                      src
# 23229  <p class="author"><a href="./viewtopic.php?p=3...
# 23230  <div class="content">Standard oring are to fat...
# 23231  <a href="./memberlist.php?mode=viewprofile&amp...
# 23232                 <dd><strong>Posts:</strong> 8</dd>
# 23233  <dd><strong>Joined:</strong> Thu Mar 07, 2013 ...

# %% [markdown]
# Make training set, which will consist of triplets of points
#
#     (anchor, positive, negative)
#
# where
#
#     - anchor and positive are of the same class
#     - anchor and negative are of different classes
#
#
#
# We'll minimize the loss function
#
#     max(0, distance(anchor, positive) - distance(anchor, negative) + margin)
#
# In this case, we use
#
#     distance(x, y) = 1 - cosine_similarity(x, y)
#
# but
#
#     distance(x, y) = euclidean_distance(x, y)
#
# also seems to work in general.

# %%
train     = make_triplet_train(df, N = 600)
trn, levs = formatter.format(train, ['obj'], 'hash')
# Out:
#   + 459fb-1706c
#   + 520fa-1706c
#   + 9ead9-1706c
#   + 34883-1706c
#   + 2e98d-1706c
#   + 2bb6e-1706c
#   + bf07b-1706c
#   + 8fbdb-1706c
#   + a1c8c-48774
#   + e5316-48774
#   + 3122c-48774
#   + df7d2-48774
#   + 5fd24-48774
#   + 58faa-48774
#   + 0dba3-48774
#   + 9acc3-48774
#   + 6d664-48774
#   + 20a50-48774
#   + b9976-48774

# %% [markdown]
# Define and train the model.  This should take several minutes on the current dataset.

# %%
classifier = TripletClassifier(trn, levs)
classifier.fit(batch_size = 250, nb_epoch = 3)

# %% [markdown]
# Create set of all unique records (without duplicates), then project them using the model.  The projection should take tens of seconds.

# %%
unq = df.copy()
del unq['id']
unq = unq.drop_duplicates()

awl, _ = formatter.format(unq, ['obj'], 'hash')
preds  = classifer.predict(awl['x'][0], verbose = True)
# Out:
# 14314/14314 [==============================] - 13s

# %% [markdown]
# Cluster the projections using DBSCAN, then interpret the cluster to be the aligned datatypes.
#
# Though the string similarity was performed on just the HTML text content, we show the classes with HTML markup so we can easily verify the cluster assignments.  Notice that some of the clusters include hashes from both schemas, while others only include hashes from a single schema -- this is desired behavior, as there is not a 1-to-1 mapping between the two schemas.

# %%
db = DBSCAN(eps = .1, min_samples = 50).fit(preds)

# Observation cluster assignments by hash
res         = unq.hash.groupby(db.labels_).apply(lambda x: x.value_counts()).reset_index()
res.columns = ('cluster', 'hash', 'cnt')

# Discard small clusters, or points that were assigned to None cluster
good_res = res[(res.cnt > 100) & (res.cluster > -1)]
eqv = list(good_res.groupby('cluster').hash.apply(lambda x: list(x)))
eqv = map(eval, np.unique(map(str, eqv)))

print '\n-----------------------'
print 'clusters, without markup'
print_eqv(eqv, df, path = 'obj')

print '\n--------------------------------------'
print 'clusters, with markup for verification'
print_eqv(eqv, df, path = 'src')
# Out:
# height has been deprecated.
#
#
# -----------------------
# clusters, without markup
#
#  ---
#
# ['3122c-48774', '9acc3-48774', '34883-1706c', '8fbdb-1706c']
#
#
# 3122c-48774	(1428 rows)
# 10253    ShawnHu wrote:How about a hammer tapping servi...
# 14293    I am totally against this, and I think you are...
# 21204    My bolt broken last night. I wanted to know if...
# 17490    This line of scopes have alot of potential and...
# 18197    HI guys, this morning I decided to try and mak...
# Name: obj, dtype: object
# 9acc3-48774	(1209 rows)
# 13566    The trigger screws do not affect the hammer tr...
# 17055    thanks for the response man I have been using ...
# 7474     All my misses are @ close range. So I guess I ...
# 6539     bstaley wrote:Got a chance to try the heat shr...
# 15720            Shawnhu,PM just sent with my contact info
# Name: obj, dtype: object
# 34883-1706c	(975 rows)
# 838     i have one too without markings on barrel . th...
# 5784    Hello, looks like a nice board to which I hope...
# 866     I would like to date a 870 wingmaster field gr...
# 998     I have ammo - Lake City Armory that was loaded...
# 35      Hi, I'm after a Lyman No.1 cocking piece peep ...
# Name: obj, dtype: object
# 8fbdb-1706c	(695 rows)
# 1014    long rifle its the one that i learned to shoot...
# 4616                What is serial number?  Jay Huber RSA
# 2959    good day:i have a first year productio 760 in ...
# 1642    You have a Remington Model 1894. From the seri...
# 4303                                     Still looking!!!
# Name: obj, dtype: object
#
#  ---
#
# ['459fb-1706c', 'df7d2-48774', '6d664-48774']
#
#
# 459fb-1706c	(978 rows)
# 4452        Guest
# 3925        RCamp
# 380     Virginian
# 847        wiktor
# 574        Dale S
# Name: obj, dtype: object
# df7d2-48774	(1397 rows)
# 15499          RayK
# 7117      Motorhead
# 8399           duga
# 9307     Marauder25
# 6999         jimmyk
# Name: obj, dtype: object
# 6d664-48774	(1172 rows)
# 20479        int3man
# 13101         eelect
# 18601          iride
# 13681    gunlocators
# 10695       dpittman
# Name: obj, dtype: object
#
#  ---
#
# ['520fa-1706c', '2bb6e-1706c']
#
#
# 520fa-1706c	(939 rows)
# 77      \nJoined: Thu May 27, 2010 9:53 amPosts: 7\n\t...
# 2210    \nJoined: Tue Oct 07, 2003 8:48 amPosts: 1\n\t...
# 3401    \nJoined: Fri Jan 22, 2010 6:31 pmPosts: 43Loc...
# 4193    \nJoined: Wed Oct 23, 2013 5:04 pmPosts: 4\n\t...
# 4139    \nJoined: Sun Dec 12, 2010 2:39 pmPosts: 4\n\t...
# Name: obj, dtype: object
# 2bb6e-1706c	(666 rows)
# 117     \nJoined: Tue Jan 22, 2008 9:27 pmPosts: 699Lo...
# 1459    \nJoined: Mon Dec 29, 2008 6:04 pmPosts: 556Lo...
# 2347    \nJoined: Sun Nov 09, 2003 2:08 pmPosts: 187Lo...
# 5854    \nJoined: Mon May 16, 2005 9:52 pmPosts: 833\n...
# 4006    \nJoined: Sun Sep 16, 2007 9:27 pmPosts: 87Loc...
# Name: obj, dtype: object
#
#  ---
#
# ['58faa-48774', 'b9976-48774', 'bf07b-1706c', '9ead9-1706c', 'a1c8c-48774']
#
#
# 58faa-48774	(1217 rows)
# 6550     Re: My Monster 45 cal xp ranger shooting over ...
# 19034                                 Re: de-ping material
# 14827              Re: Hello, another newbie saying hello.
# 22688                                   Re: .25 Kodiaks ??
# 9419                              Re: WAR no bounce hammer
# Name: obj, dtype: object
# b9976-48774	(938 rows)
# 22744          Re: NEED ADVICE FOR NITE LIGHT
# 10786                  Re: Suitable backstop?
# 10055         Re: Which Scope Did You Choose?
# 15626          Re: Pacific Airgun Expo (pics)
# 12895    Re: Black Ops Bullpup Marauder Done!
# Name: obj, dtype: object
# bf07b-1706c	(614 rows)
# 4498                 Re: Model 14 First Kill in 50+ Years
# 3285               Re: Remington model 11 help to idenify
# 330     Re: Scoremaster 511: light trigger to won't co...
# 971                                      "Old Remingtons"
# 4891                                        Classic 300 H
# Name: obj, dtype: object
# 9ead9-1706c	(919 rows)
# 146     Re: REMINGTON ROLLING BLOCK IDENTIFICATION
# 528           Model 25 failure to feed.  Need help
# 5618                Re: 16 ga 1889 info for Rem RB
# 114                    Need  help with 700 .458 ID
# 5312    Remington Model 121, Field Master 22 rifle
# Name: obj, dtype: object
# a1c8c-48774	(500 rows)
# 22987        Played with my new to me refurbished 25 M-rod
# 6544     My Monster 45 cal xp ranger shooting over 400g...
# 11074                                            POI shift
# 9585                                   Re: Highest fpe .22
# 18731    SynRod case suggestions requested-Update! foun...
# Name: obj, dtype: object
#
#  ---
#
# ['5fd24-48774', '20a50-48774']
#
#
# 5fd24-48774	(3355 rows)
# 13179                           Posts: 987
# 10526     Joined: Sat Jan 05, 2013 8:59 am
# 8333      Joined: Thu Jan 07, 2010 2:51 am
# 18996    Joined: Fri Oct 28, 2011 10:30 am
# 13009     Joined: Sat Dec 24, 2011 8:15 pm
# Name: obj, dtype: object
# 20a50-48774	(2880 rows)
# 13617     Joined: Tue Feb 22, 2011 8:05 pm
# 15075     Joined: Tue Sep 24, 2013 6:21 am
# 13297    Joined: Tue Sep 04, 2012 10:45 am
# 21059              Location: Odessa, Texas
# 18397     Joined: Thu Sep 22, 2011 9:08 am
# Name: obj, dtype: object
#
#  ---
#
# ['e5316-48774', '0dba3-48774']
#
#
# e5316-48774	(1439 rows)
# 14479        by bthrel  Tue Nov 26, 2013 10:45 am
# 19185           by hill  Wed Aug 27, 2014 6:34 am
# 18880    by IrishBandit  Thu Jun 28, 2012 6:54 pm
# 11932      by HOLLYW00D  Wed Sep 10, 2014 7:37 am
# 15200        by redboat  Tue Apr 03, 2012 5:08 pm
# Name: obj, dtype: object
# 0dba3-48774	(1217 rows)
# 9065              by darryl  Sun Aug 07, 2011 12:24 pm
# 9497                 by Doc  Tue Jul 22, 2014 10:05 am
# 19395    by Masked Marauder  Sat Jan 24, 2015 10:31 pm
# 19907                by hill  Fri Jan 10, 2014 7:35 pm
# 23100          by hammer0419  Tue Apr 29, 2014 5:51 pm
# Name: obj, dtype: object
#
# --------------------------------------
# clusters, with markup for verification
#
#  ---
#
# ['3122c-48774', '9acc3-48774', '34883-1706c', '8fbdb-1706c']
#
#
# 3122c-48774	(1428 rows)
# 16987    <div class="content">... her ugly, yet oh so f...
# 7997     <div class="content"><blockquote><div><cite>Kr...
# 11221    <div class="content">Come on peeps, dont you k...
# 21762    <div class="content"><blockquote><div><cite>sc...
# 22068                 <div class="content">good deal</div>
# Name: src, dtype: object
# 9acc3-48774	(1209 rows)
# 9958     <div class="content"><blockquote><div><cite>ha...
# 11276    <div class="content">Supercharged86 did his an...
# 18309    <div class="content">I have bought a couple pe...
# 9066     <div class="content">Is the head size a critic...
# 12944    <div class="content">I must be missing somethi...
# Name: src, dtype: object
# 34883-1706c	(975 rows)
# 4251                <div class="postbody">For Info.</div>
# 5844    <div class="postbody">Hi,<br/>New to the forum...
# 2620    <div class="postbody">Well the bluing is mostl...
# 2686    <div class="postbody">Rem725,<br/><br/>Thanks ...
# 2820    <div class="postbody">Will do Bob,  As soon as...
# Name: src, dtype: object
# 8fbdb-1706c	(695 rows)
# 5003    <div class="postbody">I finally received the l...
# 3932    <div class="postbody">Your pre-Model 12 was ma...
# 5415    <div class="postbody">Adam, your rifle predate...
# 5908    <div class="postbody">Hi Guys,<br/><br/>I have...
# 6016    <div class="postbody">I have a 7600 buttstock ...
# Name: src, dtype: object
#
#  ---
#
# ['459fb-1706c', 'df7d2-48774', '6d664-48774']
#
#
# 459fb-1706c	(978 rows)
# 5478         <div class="postauthor">HeWhoHunts</div>
# 1190             <div class="postauthor">K2unit</div>
# 5624       <div class="postauthor">Gordon Green</div>
# 1486              <div class="postauthor">Guest</div>
# 5793    <div class="postauthor">remingtondouble</div>
# Name: src, dtype: object
# df7d2-48774	(1397 rows)
# 12291    <a href="./memberlist.php?mode=viewprofile&amp...
# 18389    <a href="./memberlist.php?mode=viewprofile&amp...
# 8177     <a href="./memberlist.php?mode=viewprofile&amp...
# 14966    <a href="./memberlist.php?mode=viewprofile&amp...
# 11697    <a href="./memberlist.php?mode=viewprofile&amp...
# Name: src, dtype: object
# 6d664-48774	(1172 rows)
# 13202    <a href="./memberlist.php?mode=viewprofile&amp...
# 7840     <a href="./memberlist.php?mode=viewprofile&amp...
# 18445    <a href="./memberlist.php?mode=viewprofile&amp...
# 8350     <a href="./memberlist.php?mode=viewprofile&amp...
# 18862    <a href="./memberlist.php?mode=viewprofile&amp...
# Name: src, dtype: object
#
#  ---
#
# ['520fa-1706c', '2bb6e-1706c']
#
#
# 520fa-1706c	(939 rows)
# 389     <div class="postdetails">\n<br/><b>Joined:</b>...
# 3437    <div class="postdetails">\n<br/><b>Joined:</b>...
# 2069    <div class="postdetails">\n<br/><b>Joined:</b>...
# 5665    <div class="postdetails">\n<br/><b>Joined:</b>...
# 3886    <div class="postdetails">\n<br/><b>Joined:</b>...
# Name: src, dtype: object
# 2bb6e-1706c	(666 rows)
# 860     <div class="postdetails">\n<br/><b>Joined:</b>...
# 5738    <div class="postdetails">\n<br/><b>Joined:</b>...
# 1379    <div class="postdetails">\n<br/><b>Joined:</b>...
# 2746    <div class="postdetails">\n<br/><b>Joined:</b>...
# 2802    <div class="postdetails">\n<br/><b>Joined:</b>...
# Name: src, dtype: object
#
#  ---
#
# ['58faa-48774', 'b9976-48774', 'bf07b-1706c', '9ead9-1706c', 'a1c8c-48774']
#
#
# 58faa-48774	(1217 rows)
# 18676    <a href="#p28203">Re: New TERYX STOCK batch th...
# 21190    <a href="#p19129">Re: Anyone clean with Ballis...
# 16617    <a href="#p11866">Re: Setting the Metering sce...
# 12609    <a href="#p63502">Re: Possible 177 cal Regged ...
# 18636    <a href="#p68826">Re: Beeman Kodiaks jammed th...
# Name: src, dtype: object
# b9976-48774	(938 rows)
# 9172                     <a href="#p66491">Re: nj laws</a>
# 14125                        <a href="#p39350">Re: FNG</a>
# 18171    <a href="#p42179">Re: Mrod vs. HW100:  who win...
# 19054           <a href="#p39542">Re: de-ping material</a>
# 22656              <a href="#p6096">Re: .25 Kodiaks ??</a>
# Name: src, dtype: object
# bf07b-1706c	(614 rows)
# 5877    <div class="postsubject"><a href="./viewtopic....
# 1204    <div class="postsubject"><a href="./viewtopic....
# 4686    <div class="postsubject"><a href="./viewtopic....
# 2287    <div class="postsubject"><a href="./viewtopic....
# 2723    <div class="postsubject"><a href="./viewtopic....
# Name: src, dtype: object
# 9ead9-1706c	(919 rows)
# 2661    <div class="postsubject"><a href="./viewtopic....
# 1859    <div class="postsubject"><a href="./viewtopic....
# 5843    <div class="postsubject"><a href="./viewtopic....
# 3426    <div class="postsubject"><a href="./viewtopic....
# 4919    <div class="postsubject"><a href="./viewtopic....
# Name: src, dtype: object
# a1c8c-48774	(500 rows)
# 21073                <a href="#p3535">Re: Mrod Carbine</a>
# 13242         <a href="#p20822">trigger group sticking</a>
# 11390    <a href="#p55980">Who makes an aluminum Maraud...
# 11018    <a href="#p61602">Cocking effort, heavy with d...
# 20333    <a href="#p14483">might want to sell my mrod ....
# Name: src, dtype: object
#
#  ---
#
# ['5fd24-48774', '20a50-48774']
#
#
# 5fd24-48774	(3355 rows)
# 15372    <dd><strong>Joined:</strong> Thu Feb 10, 2011 ...
# 13259    <dd><strong>Joined:</strong> Tue Feb 22, 2011 ...
# 13520    <dd><strong>Joined:</strong> Fri Mar 23, 2012 ...
# 7407     <dd><strong>Joined:</strong> Sat Oct 18, 2014 ...
# 9824                   <dd><strong>Posts:</strong> 38</dd>
# Name: src, dtype: object
# 20a50-48774	(2880 rows)
# 9960                  <dd><strong>Posts:</strong> 461</dd>
# 18088    <dd><strong>Joined:</strong> Sun Nov 01, 2009 ...
# 16157    <dd><strong>Joined:</strong> Sat Jun 05, 2010 ...
# 8250                  <dd><strong>Posts:</strong> 321</dd>
# 9462     <dd><strong>Location:</strong> Central Texas</dd>
# Name: src, dtype: object
#
#  ---
#
# ['e5316-48774', '0dba3-48774']
#
#
# e5316-48774	(1439 rows)
# 13961    <p class="author"><a href="./viewtopic.php?p=7...
# 14574    <p class="author"><a href="./viewtopic.php?p=6...
# 11404    <p class="author"><a href="./viewtopic.php?p=5...
# 9384     <p class="author"><a href="./viewtopic.php?p=2...
# 14267    <p class="author"><a href="./viewtopic.php?p=2...
# Name: src, dtype: object
# 0dba3-48774	(1217 rows)
# 21519    <p class="author"><a href="./viewtopic.php?p=3...
# 12666    <p class="author"><a href="./viewtopic.php?p=3...
# 17210    <p class="author"><a href="./viewtopic.php?p=2...
# 13182    <p class="author"><a href="./viewtopic.php?p=4...
# 21828    <p class="author"><a href="./viewtopic.php?p=4...
# Name: src, dtype: object
